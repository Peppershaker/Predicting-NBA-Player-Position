# %%
import sys
sys.path.append('/Users/victor/Documents/code/nba_api')

from nba_py import game, player, team, shotchart
import pandas as pd

# %%
players = player.PlayerList().info()

# %%
players
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST      DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0       203518            Abrines, Alex            Alex Abrines             0
# 1       203112              Acy, Quincy              Quincy Acy             0
# 2      1629121            Adams, Jaylen            Jaylen Adams             1
# 3       203500            Adams, Steven            Steven Adams             1
# 4      1628389             Adebayo, Bam             Bam Adebayo             1
# 5      1629061               Adel, Deng               Deng Adel             1
# 6      1629152  Akoon-Purcell, DeVaughn  DeVaughn Akoon-Purcell             0
# 7       200746       Aldridge, LaMarcus       LaMarcus Aldridge             1
# 8      1628959            Alkins, Rawle            Rawle Alkins             1
# 9      1628960           Allen, Grayson           Grayson Allen             1
# 10     1628386           Allen, Jarrett           Jarrett Allen             1
# ...

# %%
players[players.PERSON_ID == 1626780]
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 186    1626780         Gibson, Jonathan    Jonathan Gibson             1
#
#     FROM_YEAR TO_YEAR       PLAYERCODE     TEAM_ID TEAM_CITY TEAM_NAME  \
# 186      2016    2018  jonathan_gibson  1610612738    Boston   Celtics
#
#     TEAM_ABBREVIATION TEAM_CODE GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 186               BOS   celtics                 Y                        00

# %%
player.get_player("Siakam")
# Out:
# ---------------------------------------------------------------------------
# PlayerNotFoundException                   Traceback (most recent call last)
# <ipython-input-6-f46101103e92> in <module>()
# ----> 1 player.get_player("Siakam")
#
# ~/Documents/code/nba_api/nba_py/player.py in get_player(first_name, last_name, season, only_current, just_id)
#      40         item = next(plyr for plyr in pl if str(plyr[hdr]).lower() == name)
#      41     if len(item) == 0:
# ---> 42         raise PlayerNotFoundException
#      43     elif just_id:
#      44         return item['PERSON_ID']
#
# PlayerNotFoundException:

# %%
# Toronto team number 1610612761
team.TeamList().info()
# Out:
#    LEAGUE_ID     TEAM_ID MIN_YEAR MAX_YEAR ABBREVIATION
# 0         00  1610612737     1949     2018          ATL
# 1         00  1610612738     1946     2018          BOS
# 2         00  1610612739     1970     2018          CLE
# 3         00  1610612740     2002     2018          NOP
# 4         00  1610612741     1966     2018          CHI
# 5         00  1610612742     1980     2018          DAL
# 6         00  1610612743     1976     2018          DEN
# 7         00  1610612744     1946     2018          GSW
# 8         00  1610612745     1967     2018          HOU
# 9         00  1610612746     1970     2018          LAC
# 10        00  1610612747     1948     2018          LAL
# 11        00  1610612748     1988     2018          MIA
# 12        00  1610612750     1989     2018          MIN
# 13        00  1610612751     1976     2018          BKN
# 14        00  1610612752     1946     2018          NYK
# 15        00  1610612753     1989     2018          ORL
# ...

# %%
team.TeamGameLogs(1610612761, season_type="Playoffs").info()
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP WL  W  L  W_PCT  MIN  \
# 0   1610612761  0041800401  MAY 30, 2019  TOR vs. GSW  W  1  0  1.000  240
# 1   1610612761  0041800306  MAY 25, 2019  TOR vs. MIL  W  4  2  0.667  240
# 2   1610612761  0041800305  MAY 23, 2019    TOR @ MIL  W  3  2  0.600  240
# 3   1610612761  0041800304  MAY 21, 2019  TOR vs. MIL  W  2  2  0.500  240
# 4   1610612761  0041800303  MAY 19, 2019  TOR vs. MIL  W  1  2  0.333  290
# 5   1610612761  0041800302  MAY 17, 2019    TOR @ MIL  L  0  2  0.000  240
# 6   1610612761  0041800301  MAY 15, 2019    TOR @ MIL  L  0  1  0.000  240
# 7   1610612761  0041800217  MAY 12, 2019  TOR vs. PHI  W  4  3  0.571  240
# 8   1610612761  0041800216  MAY 09, 2019    TOR @ PHI  L  3  3  0.500  240
# 9   1610612761  0041800215  MAY 07, 2019  TOR vs. PHI  W  3  2  0.600  240
# 10  1610612761  0041800214  MAY 05, 2019    TOR @ PHI  W  2  2  0.500  240
# ...

# %%
game.PlayerTracking('0041800401').info().to_csv("game.csv")

# %%
# !open .

# %%
shotchart.ShotChart(1627783).shot_chart()
# Out:
#              GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0    Shot Chart Detail  0021800008             36    1627783  Pascal Siakam
# 1    Shot Chart Detail  0021800008             56    1627783  Pascal Siakam
# 2    Shot Chart Detail  0021800008            233    1627783  Pascal Siakam
# 3    Shot Chart Detail  0021800008            257    1627783  Pascal Siakam
# 4    Shot Chart Detail  0021800008            407    1627783  Pascal Siakam
# 5    Shot Chart Detail  0021800008            411    1627783  Pascal Siakam
# 6    Shot Chart Detail  0021800008            427    1627783  Pascal Siakam
# 7    Shot Chart Detail  0021800008            438    1627783  Pascal Siakam
# 8    Shot Chart Detail  0021800019             30    1627783  Pascal Siakam
# 9    Shot Chart Detail  0021800019             79    1627783  Pascal Siakam
# 10   Shot Chart Detail  0021800019             82    1627783  Pascal Siakam
# ...
